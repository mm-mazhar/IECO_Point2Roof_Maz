# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !nvidia-smi
# Out:
# Fri Sep 27 10:38:02 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import torch
print(f"Torch + Cuda Version: {torch.__version__}")
print(f"Cuda Version Requied: {torch.version.cuda}")
print(f"Cuda Available: {torch.cuda.is_available()}")
print(f"Cuda Device Count: {torch.cuda.device_count()}")
print(f"Cuda Device Name: {torch.cuda.get_device_name(0)}")
# Out:
# Torch + Cuda Version: 2.4.1+cu121
# Cuda Version Requied: 12.1
# Cuda Available: True
# Cuda Device Count: 1
# Cuda Device Name: Tesla T4

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# %pwd
# Out:
# '/content'

# %%
TEST_DATA = "/content/drive/MyDrive/dataset_colob"
TEST_TAG = "test_run_colab"
OUTPUT_DIR = f"/content/IECO_Point2Roof_Maz/output/{TEST_TAG}"

# %%
# %cd /content
# !git clone https://github.com/mm-mazhar/IECO_Point2Roof_Maz.git
# %cd /content/IECO_Point2Roof_Maz
# Out:
# Cloning into 'IECO_Point2Roof_Maz'...
# remote: Enumerating objects: 146, done.
# remote: Counting objects: 100% (146/146), done.
# remote: Compressing objects: 100% (138/138), done.
# remote: Total 146 (delta 7), reused 146 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (146/146), 13.34 MiB | 17.53 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# /content/IECO_Point2Roof_Maz

# %%
# !pip install ninja -q
# !pip install --upgrade torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121 -q
# !pip install torch-scatter torch-sparse torch-cluster torch-spline-conv torch-geometric -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 16.6 MB/s eta 0:00:00

# %%
# Navigate to pc_util and rebuild
# %cd pc_util

# !python setup.py build_ext --inplace
# !python setup.py install

# %cd ..

####################################################
# %cd pc_util

# # Build the extension in-place
# !python setup.py build_ext --inplace

# # Install the package using pip (instead of setup.py install)
# !pip install .

# %cd ..
# Out:
# /content/IECO_Point2Roof_Maz/pc_util
# running build_ext
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:414: UserWarning: The detected CUDA version (12.2) has a minor version mismatch with the version that was used to compile PyTorch (12.1). Most likely this shouldn't be a problem.
#   warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:424: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.2
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# building 'pc_util' extension
# creating /content/IECO_Point2Roof_Maz/pc_util/build
# creating /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310
# creating /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:1965: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Emitting ninja build file /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/build.ninja...
# Compiling objects...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/11] c++ -MMD -MF /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/ball_query.o.d -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.10/dist-packages/torch/include -I/usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.10/dist-packages/torch/include/TH -I/usr/local/lib/python3.10/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.10 -c -c /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp -o /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/ball_query.o -g -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=pc_util -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++17
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp: In function ‘int ball_query_wrapper_fast(int, int, int, float, int, at::Tensor, at::Tensor, at::Tensor)’:
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:13:20: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    13 |         if (!x.type().is_cuda())                                                          \
#       |                    ^
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:29:5: note: in expansion of macro ‘CHECK_CUDA’
#    29 |     CHECK_CUDA(x);     \
#       |     ^~~~~~~~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:35:5: note: in expansion of macro ‘CHECK_INPUT’
#    35 |     CHECK_INPUT(new_xyz_tensor);
#       |     ^~~~~~~~~~~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:225:30: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       |                              ^~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:13:20: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    13 |         if (!x.type().is_cuda())                                                          \
#       |                    ^
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:29:5: note: in expansion of macro ‘CHECK_CUDA’
#    29 |     CHECK_CUDA(x);     \
#       |     ^~~~~~~~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:36:5: note: in expansion of macro ‘CHECK_INPUT’
#    36 |     CHECK_INPUT(xyz_tensor);
#       |     ^~~~~~~~~~~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:225:30: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       |                              ^~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:37:54: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    37 |     const float *new_xyz = new_xyz_tensor.data<float>();
#       |                            ~~~~~~~~~~~~~~~~~~~~~~~~~~^~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:7: note: declared here
#   247 |   T * data() const {
#       |       ^~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:38:46: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    38 |     const float *xyz = xyz_tensor.data<float>();
#       |                        ~~~~~~~~~~~~~~~~~~~~~~^~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:7: note: declared here
#   247 |   T * data() const {
#       |       ^~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:39:36: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    39 |     int *idx = idx_tensor.data<int>();
#       |                ~~~~~~~~~~~~~~~~~~~~^~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:7: note: declared here
#   247 |   T * data() const {
#       |       ^~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp: In function ‘int ball_center_query_wrapper_fast(int, int, int, float, at::Tensor, at::Tensor, at::Tensor)’:
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:13:20: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    13 |         if (!x.type().is_cuda())                                                          \
#       |                    ^
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:29:5: note: in expansion of macro ‘CHECK_CUDA’
#    29 |     CHECK_CUDA(x);     \
#       |     ^~~~~~~~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:48:5: note: in expansion of macro ‘CHECK_INPUT’
#    48 |     CHECK_INPUT(point_tensor);
#       |     ^~~~~~~~~~~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:225:30: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       |                              ^~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:13:20: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    13 |         if (!x.type().is_cuda())                                                          \
#       |                    ^
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:29:5: note: in expansion of macro ‘CHECK_CUDA’
#    29 |     CHECK_CUDA(x);     \
#       |     ^~~~~~~~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:49:5: note: in expansion of macro ‘CHECK_INPUT’
#    49 |     CHECK_INPUT(key_point_tensor);
#       |     ^~~~~~~~~~~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:225:30: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       |                              ^~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:50:50: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    50 |     const float *point = point_tensor.data<float>();
#       |                          ~~~~~~~~~~~~~~~~~~~~~~~~^~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:7: note: declared here
#   247 |   T * data() const {
#       |       ^~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:51:58: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    51 |     const float *key_point = key_point_tensor.data<float>();
#       |                              ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:7: note: declared here
#   247 |   T * data() const {
#       |       ^~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:52:36: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    52 |     int *idx = idx_tensor.data<int>();
#       |                ~~~~~~~~~~~~~~~~~~~~^~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:7: note: declared here
#   247 |   T * data() const {
#       |       ^~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp: In function ‘int knn_query_wrapper_fast(int, int, int, int, at::Tensor, at::Tensor, at::Tensor, at::Tensor)’:
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:13:20: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    13 |         if (!x.type().is_cuda())                                                          \
#       |                    ^
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:29:5: note: in expansion of macro ‘CHECK_CUDA’
#    29 |     CHECK_CUDA(x);     \
#       |     ^~~~~~~~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:61:5: note: in expansion of macro ‘CHECK_INPUT’
#    61 |     CHECK_INPUT(new_xyz_tensor);
#       |     ^~~~~~~~~~~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:225:30: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       |                              ^~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:13:20: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    13 |         if (!x.type().is_cuda())                                                          \
#       |                    ^
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:29:5: note: in expansion of macro ‘CHECK_CUDA’
#    29 |     CHECK_CUDA(x);     \
#       |     ^~~~~~~~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:62:5: note: in expansion of macro ‘CHECK_INPUT’
#    62 |     CHECK_INPUT(xyz_tensor);
#       |     ^~~~~~~~~~~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:225:30: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       |                              ^~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:63:54: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    63 |     const float *new_xyz = new_xyz_tensor.data<float>();
#       |                            ~~~~~~~~~~~~~~~~~~~~~~~~~~^~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:7: note: declared here
#   247 |   T * data() const {
#       |       ^~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:64:46: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    64 |     const float *xyz = xyz_tensor.data<float>();
#       |                        ~~~~~~~~~~~~~~~~~~~~~~^~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:7: note: declared here
#   247 |   T * data() const {
#       |       ^~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:65:44: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    65 |     float *dist2 = dist2_tensor.data<float>();
#       |                    ~~~~~~~~~~~~~~~~~~~~~~~~^~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:7: note: declared here
#   247 |   T * data() const {
#       |       ^~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:66:36: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    66 |     int *idx = idx_tensor.data<int>();
#       |                ~~~~~~~~~~~~~~~~~~~~^~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:7: note: declared here
#   247 |   T * data() const {
#       |       ^~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp: In function ‘int ball_query_wrapper_stack(int, int, float, int, at::Tensor, at::Tensor, at::Tensor, at::Tensor, at::Tensor)’:
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:13:20: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    13 |         if (!x.type().is_cuda())                                                          \
#       |                    ^
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:29:5: note: in expansion of macro ‘CHECK_CUDA’
#    29 |     CHECK_CUDA(x);     \
#       |     ^~~~~~~~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:76:5: note: in expansion of macro ‘CHECK_INPUT’
#    76 |     CHECK_INPUT(new_xyz_tensor);
#       |     ^~~~~~~~~~~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:225:30: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       |                              ^~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:13:20: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    13 |         if (!x.type().is_cuda())                                                          \
#       |                    ^
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:29:5: note: in expansion of macro ‘CHECK_CUDA’
#    29 |     CHECK_CUDA(x);     \
#       |     ^~~~~~~~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:77:5: note: in expansion of macro ‘CHECK_INPUT’
#    77 |     CHECK_INPUT(xyz_tensor);
#       |     ^~~~~~~~~~~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:225:30: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       |                              ^~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:13:20: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    13 |         if (!x.type().is_cuda())                                                          \
#       |                    ^
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:29:5: note: in expansion of macro ‘CHECK_CUDA’
#    29 |     CHECK_CUDA(x);     \
#       |     ^~~~~~~~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:78:5: note: in expansion of macro ‘CHECK_INPUT’
#    78 |     CHECK_INPUT(new_xyz_batch_cnt_tensor);
#       |     ^~~~~~~~~~~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:225:30: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       |                              ^~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:13:20: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    13 |         if (!x.type().is_cuda())                                                          \
#       |                    ^
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:29:5: note: in expansion of macro ‘CHECK_CUDA’
#    29 |     CHECK_CUDA(x);     \
#       |     ^~~~~~~~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:79:5: note: in expansion of macro ‘CHECK_INPUT’
#    79 |     CHECK_INPUT(xyz_batch_cnt_tensor);
#       |     ^~~~~~~~~~~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:225:30: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       |                              ^~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:81:54: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    81 |     const float *new_xyz = new_xyz_tensor.data<float>();
#       |                            ~~~~~~~~~~~~~~~~~~~~~~~~~~^~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:7: note: declared here
#   247 |   T * data() const {
#       |       ^~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:82:46: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    82 |     const float *xyz = xyz_tensor.data<float>();
#       |                        ~~~~~~~~~~~~~~~~~~~~~~^~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:7: note: declared here
#   247 |   T * data() const {
#       |       ^~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:83:70: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    83 |     const int *new_xyz_batch_cnt = new_xyz_batch_cnt_tensor.data<int>();
#       |                                    ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:7: note: declared here
#   247 |   T * data() const {
#       |       ^~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/ball_query.cpp:84:62: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    84 |     const int *xyz_batch_cnt = xyz_batch_cnt_tensor.data<int>();
#       |                                ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
# ...
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/sampling.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:7: note: declared here
#   247 |   T * data() const {
#       |       ^~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/sampling.cpp: In function ‘int furthest_point_sampling_wrapper(int, int, int, int, float, float, at::Tensor, at::Tensor, at::Tensor)’:
# /content/IECO_Point2Roof_Maz/pc_util/src/sampling.cpp:37:52: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    37 |     const float *points = points_tensor.data<float>();
#       |                           ~~~~~~~~~~~~~~~~~~~~~~~~~^~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/sampling.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:7: note: declared here
#   247 |   T * data() const {
#       |       ^~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/sampling.cpp:38:42: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    38 |     float *temp = temp_tensor.data<float>();
#       |                   ~~~~~~~~~~~~~~~~~~~~~~~^~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/sampling.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:7: note: declared here
#   247 |   T * data() const {
#       |       ^~~~
# /content/IECO_Point2Roof_Maz/pc_util/src/sampling.cpp:39:36: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    39 |     int *idx = idx_tensor.data<int>();
#       |                ~~~~~~~~~~~~~~~~~~~~^~
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/jit/api/module.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/serialize/tensor.h:3,
#                  from /content/IECO_Point2Roof_Maz/pc_util/src/sampling.cpp:1:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:7: note: declared here
#   247 |   T * data() const {
#       |       ^~~~
# [9/11] c++ -MMD -MF /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/pointnet2_api.o.d -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.10/dist-packages/torch/include -I/usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.10/dist-packages/torch/include/TH -I/usr/local/lib/python3.10/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.10 -c -c /content/IECO_Point2Roof_Maz/pc_util/src/pointnet2_api.cpp -o /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/pointnet2_api.o -g -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=pc_util -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++17
# [10/11] /usr/local/cuda/bin/nvcc --generate-dependencies-with-compile --dependency-output /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/interpolate_gpu.o.d -I/usr/local/lib/python3.10/dist-packages/torch/include -I/usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.10/dist-packages/torch/include/TH -I/usr/local/lib/python3.10/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.10 -c -c /content/IECO_Point2Roof_Maz/pc_util/src/interpolate_gpu.cu -o /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/interpolate_gpu.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options ''"'"'-fPIC'"'"'' -O2 -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=pc_util -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_75,code=compute_75 -gencode=arch=compute_75,code=sm_75 -std=c++17
# [11/11] /usr/local/cuda/bin/nvcc --generate-dependencies-with-compile --dependency-output /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/sampling_gpu.o.d -I/usr/local/lib/python3.10/dist-packages/torch/include -I/usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.10/dist-packages/torch/include/TH -I/usr/local/lib/python3.10/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.10 -c -c /content/IECO_Point2Roof_Maz/pc_util/src/sampling_gpu.cu -o /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/sampling_gpu.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options ''"'"'-fPIC'"'"'' -O2 -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=pc_util -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_75,code=compute_75 -gencode=arch=compute_75,code=sm_75 -std=c++17
# creating build/lib.linux-x86_64-cpython-310
# x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/ball_query.o /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/ball_query_gpu.o /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/cluster.o /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/cluster_gpu.o /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/group_points.o /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/group_points_gpu.o /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/interpolate.o /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/interpolate_gpu.o /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/pointnet2_api.o /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/sampling.o /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/sampling_gpu.o -L/usr/local/lib/python3.10/dist-packages/torch/lib -L/usr/local/cuda/lib64 -L/usr/lib/x86_64-linux-gnu -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-cpython-310/pc_util.cpython-310-x86_64-linux-gnu.so
# copying build/lib.linux-x86_64-cpython-310/pc_util.cpython-310-x86_64-linux-gnu.so ->
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating pc_util.egg-info
# writing pc_util.egg-info/PKG-INFO
# writing dependency_links to pc_util.egg-info/dependency_links.txt
# writing top-level names to pc_util.egg-info/top_level.txt
# writing manifest file 'pc_util.egg-info/SOURCES.txt'
# reading manifest file 'pc_util.egg-info/SOURCES.txt'
# writing manifest file 'pc_util.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_ext
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:414: UserWarning: The detected CUDA version (12.2) has a minor version mismatch with the version that was used to compile PyTorch (12.1). Most likely this shouldn't be a problem.
#   warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:424: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.2
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# building 'pc_util' extension
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:1965: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Emitting ninja build file /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/build.ninja...
# Compiling objects...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/ball_query.o /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/ball_query_gpu.o /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/cluster.o /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/cluster_gpu.o /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/group_points.o /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/group_points_gpu.o /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/interpolate.o /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/interpolate_gpu.o /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/pointnet2_api.o /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/sampling.o /content/IECO_Point2Roof_Maz/pc_util/build/temp.linux-x86_64-cpython-310/src/sampling_gpu.o -L/usr/local/lib/python3.10/dist-packages/torch/lib -L/usr/local/cuda/lib64 -L/usr/lib/x86_64-linux-gnu -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-cpython-310/pc_util.cpython-310-x86_64-linux-gnu.so
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# copying build/lib.linux-x86_64-cpython-310/pc_util.cpython-310-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg
# creating stub loader for pc_util.cpython-310-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/pc_util.py to pc_util.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying pc_util.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pc_util.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pc_util.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pc_util.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# __pycache__.pc_util.cpython-310: module references __file__
# creating dist
# creating 'dist/pc_util-1.0-py3.10-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing pc_util-1.0-py3.10-linux-x86_64.egg
# creating /usr/local/lib/python3.10/dist-packages/pc_util-1.0-py3.10-linux-x86_64.egg
# Extracting pc_util-1.0-py3.10-linux-x86_64.egg to /usr/local/lib/python3.10/dist-packages
# Adding pc-util 1.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/pc_util-1.0-py3.10-linux-x86_64.egg
# Processing dependencies for pc-util==1.0
# Finished processing dependencies for pc-util==1.0
# /content/IECO_Point2Roof_Maz

# %%
# !mkdir -p log
# !mv ./checkpoint_epoch_90.pth OUTPUT_DIR/

# %%
# !mkdir -p {OUTPUT_DIR}

# %%
# %pwd
# Out:
# '/content/IECO_Point2Roof_Maz'

# %%
# %ls
# Out:
# dataset/  model/          pc_util/      results/  test_util.py  train_utils.py
# LICENSE   model_cfg.yaml  pointnet2.py  test.py   train.py      utils/
# log/      output/         README.md     test.txt  train.txt

# %%
# !python ./test.py --data_path {TEST_DATA} --cfg_file ./model_cfg.yaml --batch_size 1 --gpu 0 --test_tag {TEST_TAG}
# Out:
# 2024-09-27 10:59:32,027   INFO  **********************Start logging**********************
# 2024-09-27 10:59:32,027   INFO  data_path        /content/drive/MyDrive/dataset_colob
# 2024-09-27 10:59:32,027   INFO  cfg_file         ./model_cfg.yaml
# 2024-09-27 10:59:32,027   INFO  batch_size       1
# 2024-09-27 10:59:32,027   INFO  gpu              0
# 2024-09-27 10:59:32,028   INFO  test_tag         test_run_colab
# 2024-09-27 10:59:32,028   INFO
# cfg.DATA = edict()
# 2024-09-27 10:59:32,028   INFO  cfg.DATA.NPOINT: 1024
# 2024-09-27 10:59:32,028   INFO
# cfg.MODEL = edict()
# 2024-09-27 10:59:32,028   INFO
# cfg.MODEL.PointNet2 = edict()
# 2024-09-27 10:59:32,028   INFO  cfg.MODEL.PointNet2.PosRadius: 0.15
# 2024-09-27 10:59:32,028   INFO
# cfg.MODEL.PointNet2.LossWeight = edict()
# 2024-09-27 10:59:32,028   INFO  cfg.MODEL.PointNet2.LossWeight.cls_weight: 1.0
# 2024-09-27 10:59:32,028   INFO  cfg.MODEL.PointNet2.LossWeight.reg_weight: 1.0
# 2024-09-27 10:59:32,028   INFO
# cfg.MODEL.ClusterRefineNet = edict()
# 2024-09-27 10:59:32,028   INFO  cfg.MODEL.ClusterRefineNet.ScoreThresh: 0.5
# 2024-09-27 10:59:32,028   INFO  cfg.MODEL.ClusterRefineNet.MatchRadius: 0.2
# 2024-09-27 10:59:32,028   INFO
# cfg.MODEL.ClusterRefineNet.Cluster = edict()
# 2024-09-27 10:59:32,028   INFO  cfg.MODEL.ClusterRefineNet.Cluster.eps: 0.05
# 2024-09-27 10:59:32,028   INFO  cfg.MODEL.ClusterRefineNet.Cluster.min_pts: 5
# 2024-09-27 10:59:32,028   INFO
# cfg.MODEL.ClusterRefineNet.RefineSA = edict()
# 2024-09-27 10:59:32,028   INFO  cfg.MODEL.ClusterRefineNet.RefineSA.Radii: [0.1, 0.2]
# 2024-09-27 10:59:32,029   INFO  cfg.MODEL.ClusterRefineNet.RefineSA.Nsamples: [16, 16]
# 2024-09-27 10:59:32,029   INFO  cfg.MODEL.ClusterRefineNet.RefineSA.MLPs: [[128, 128], [128, 128]]
# 2024-09-27 10:59:32,029   INFO
# cfg.MODEL.ClusterRefineNet.LossWeight = edict()
# 2024-09-27 10:59:32,029   INFO  cfg.MODEL.ClusterRefineNet.LossWeight.reg_weight: 1.0
# 2024-09-27 10:59:32,029   INFO
# cfg.MODEL.EdgeAttentionNet = edict()
# 2024-09-27 10:59:32,029   INFO
# cfg.MODEL.EdgeAttentionNet.LossWeight = edict()
# 2024-09-27 10:59:32,029   INFO  cfg.MODEL.EdgeAttentionNet.LossWeight.cls_weight: 1.0
# 2024-09-27 10:59:32,029   INFO  cfg.ROOT_DIR: /content/IECO_Point2Roof_Maz
# 2024-09-27 10:59:32,032   INFO  Total samples: 5
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 2024-09-27 10:59:32,270   INFO  ==> Loading parameters from checkpoint
# /content/IECO_Point2Roof_Maz/model/model_utils.py:89: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename)
# 2024-09-27 10:59:32,381   INFO  ==> Done
# 2024-09-27 10:59:32,382   INFO  **********************Start testing**********************
# 2024-09-27 10:59:32,383   INFO  RoofNet(
#   (keypoint_det_net): PointNet2(
#     (sa1): PointNetSAModule(
#       (groupers): ModuleList(
#         (0): QueryAndGroup()
#       )
#       (mlps): ModuleList(
#         (0): Conv2ds(
#           (conv1): Conv2dBN(
#             (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv): Conv2d(6, 32, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv2): Conv2dBN(
#             (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv3): Conv2dBN(
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#     )
#     (sa2): PointNetSAModule(
#       (groupers): ModuleList(
#         (0): QueryAndGroup()
#       )
#       (mlps): ModuleList(
#         (0): Conv2ds(
#           (conv1): Conv2dBN(
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv): Conv2d(67, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv2): Conv2dBN(
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv3): Conv2dBN(
#             (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#     )
#     (sa3): PointNetSAModule(
#       (groupers): ModuleList(
#         (0): QueryAndGroup()
#       )
#       (mlps): ModuleList(
#         (0): Conv2ds(
#           (conv1): Conv2dBN(
#             (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv): Conv2d(131, 128, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv2): Conv2dBN(
#             (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv3): Conv2dBN(
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#     )
#     (sa4): PointNetSAModule(
#       (groupers): ModuleList(
#         (0): QueryAndGroup()
#       )
#       (mlps): ModuleList(
#         (0): Conv2ds(
#           (conv1): Conv2dBN(
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv): Conv2d(259, 256, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv2): Conv2dBN(
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv3): Conv2dBN(
#             (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#     )
#     (fp4): PointNetFPModule(
#       (mlp): Conv2ds(
#         (conv1): Conv2dBN(
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv): Conv2d(768, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv2): Conv2dBN(
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#     )
#     (fp3): PointNetFPModule(
#       (mlp): Conv2ds(
#         (conv1): Conv2dBN(
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv2): Conv2dBN(
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#     )
#     (fp2): PointNetFPModule(
#       (mlp): Conv2ds(
#         (conv1): Conv2dBN(
#           (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv): Conv2d(320, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv2): Conv2dBN(
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#     )
#     (fp1): PointNetFPModule(
#       (mlp): Conv2ds(
#         (conv1): Conv2dBN(
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv2): Conv2dBN(
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv3): Conv2dBN(
#           (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#     )
#     (shared_fc): Conv1dBN(
#       (bn): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#     )
#     (drop): Dropout(p=0.5, inplace=False)
#     (offset_fc): Conv1d(128, 3, kernel_size=(1,), stride=(1,))
#     (cls_fc): Conv1d(128, 1, kernel_size=(1,), stride=(1,))
#     (cls_loss_func): SigmoidBCELoss()
#     (reg_loss_func): WeightedSmoothL1Loss()
#   )
#   (cluster_refine_net): ClusterRefineNet(
#     (matcher): HungarianMatcher()
#     (fea_refine_module): StackSAModuleMSG(
#       (groupers): ModuleList(
#         (0-1): 2 x QueryAndGroup()
#       )
#       (mlps): ModuleList(
#         (0-1): 2 x Sequential(
#           (0): Conv2d(131, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#           (3): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU()
#         )
#       )
#     )
#     (shared_fc): LinearBN(
#       (bn): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv): Linear(in_features=256, out_features=128, bias=True)
#     )
#     (drop): Dropout(p=0.5, inplace=False)
#     (offset_fc): Linear(in_features=128, out_features=3, bias=True)
#     (reg_loss_func): WeightedSmoothL1Loss()
#   )
#   (edge_att_net): EdgeAttentionNet(
#     (att_layer): PairedPointAttention(
#       (edge_att1): Sequential(
#         (0): Linear(in_features=256, out_features=256, bias=True)
#         (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Linear(in_features=256, out_features=256, bias=True)
#         (4): Sigmoid()
#       )
#       (edge_att2): Sequential(
#         (0): Linear(in_features=256, out_features=256, bias=True)
#         (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Linear(in_features=256, out_features=256, bias=True)
#         (4): Sigmoid()
#       )
#       (fea_fusion_layer): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (shared_fc): LinearBN(
#       (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (drop): Dropout(p=0.5, inplace=False)
#     (cls_fc): Linear(in_features=256, out_features=1, bias=True)
#     (cls_loss_func): SigmoidBCELoss()
#   )
# )
# test:   0% 0/5 [00:00<?, ?it/s]/content/IECO_Point2Roof_Maz/model/pointnet_util.py:27: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:78.)
#   output = torch.cuda.IntTensor(B, npoint)
# test: 100% 5/5 [00:03<00:00,  1.55it/s]
# 2024-09-27 10:59:36,029   INFO  pts_recall: 0.551724
# 2024-09-27 10:59:36,030   INFO  pts_precision: 0.888889
# 2024-09-27 10:59:36,030   INFO  pts_bias: 0.669026, 0.524627, 0.091398
# 2024-09-27 10:59:36,030   INFO  edge_recall: 0.375000
# 2024-09-27 10:59:36,030   INFO  edge_precision: 1.000000

# %%
# /content/IECO_Point2Roof_Maz/output/test_run_colab/checkpoint_epoch_90.pth

# %%
import pc_util
print(dir(pc_util))  # Check if 'furthest_point_sampling_wrapper' is listed
# Out:
# ['__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__']

# %%
# Out:
# 2.4.1+cu121
# 12.1

# %%
# %cd /content
# !GIT_LFS_SKIP_SMUDGE=1 git clone -b dev https://github.com/Li-Li-Whu/Point2Roof
# %cd /content/InstantMesh

# %%
# %cd "/content/drive/Othercomputers/My Laptop/IECO_Maz"
# CURRENCT_WORKING_DIR = %pwd
# print(f"Current Working Directory Now: '{CURRENCT_WORKING_DIR}'")

# %%
# # Clone the repository
# !git clone https://github.com/mm-mazhar/IECO_3D_Model_Reconstruction_DL.git
# # Change to the repository directory
# %cd /content/drive/Othercomputers/My Laptop/IECO_Maz/IECO_3D_Model_Reconstruction_DL
# # List the files in the repository
# !ls

# %%
# !conda env update -n base -f ./requirements/requirements_colab.yml --quiet

# %%
# CURRENCT_WORKING_DIR = %pwd
# print(f"Current Working Directory Now: '{CURRENCT_WORKING_DIR}'")

# %%
# import open3d as o3d
# import numpy as np
# import PIL.Image
# import IPython.display
# import os
# import urllib
# import tarfile
# import gzip
# import zipfile
# import shutil
